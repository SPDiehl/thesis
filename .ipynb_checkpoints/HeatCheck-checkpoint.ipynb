# %% [markdown]
# # Data Analysis

# %%
import pandas as pd
import numpy as np
import xgboost as xgb
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# /Users/seandiehl/opt/anaconda3/envs/thesis-env/lib/python3.9/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index

# %%
pd.set_option('display.max_columns', None)

df = pd.read_csv('/Users/seandiehl/Desktop/PBP-1819.csv')
df.head()
# Out:
#     X1     GAME_ID  PLAYER1_ID  PLAYER1_NAME  PLAYER1_TEAM_ID  PLAYER2_ID  \
# 0  NaN         NaN         NaN           NaN              NaN         NaN
# 1  0.0  21801052.0         0.0           NaN              NaN         0.0
# 2  1.0  21801052.0    201143.0    Al Horford     1.610613e+09    203999.0
# 3  2.0  21801052.0    200794.0  Paul Millsap     1.610613e+09         0.0
# 4  3.0  21801052.0   1628369.0  Jayson Tatum     1.610613e+09         0.0
#
#    PLAYER2_NAME  PLAYER3_ID  PLAYER3_NAME  TIME  ASSIST_PLAYER_ID  \
# 0           NaN         NaN           NaN   NaN               NaN
# 1           NaN         0.0           NaN   0.0               NaN
# 2  Nikola Jokic    200794.0  Paul Millsap   0.0               NaN
# 3           NaN         0.0           NaN  19.0               NaN
# 4           NaN         0.0           NaN  21.0               NaN
#
#    ASSIST_COUNT  BLOCK_PLAYER_ID  BLOCK_COUNT  REBOUND_PLAYER_ID REBOUND_TEAM  \
# ...

# %%
projs = pd.read_csv('/Users/seandiehl/Desktop/projections-per-sec1819.csv')
projs.head()
# Out:
#    Unnamed: 0  Rk                       Player       Type        FG       FGA  \
# 0           0   1      Álex Abrines\abrinal01  Projected  0.001944  0.004722
# 1           2   2           Quincy Acy\acyqu01  Projected  0.001806  0.004676
# 2           4   3       Steven Adams\adamsst01  Projected  0.002824  0.004676
# 3           6   4        Bam Adebayo\adebaba01  Projected  0.002269  0.004352
# 4           8   5  LaMarcus Aldridge\aldrila01  Projected  0.004120  0.008333
#
#          3P       3PA        FT       FTA       ORB       TRB       AST  \
# 0  0.001296  0.003287  0.000694  0.000787  0.000370  0.001713  0.000602
# 1  0.001111  0.003102  0.000787  0.000972  0.000556  0.003194  0.000741
# 2  0.000046  0.000093  0.001065  0.001852  0.002269  0.004491  0.000648
# 3  0.000093  0.000278  0.001574  0.002130  0.001389  0.004583  0.001296
# 4  0.000185  0.000556  0.001944  0.002361  0.001435  0.004028  0.001019
#
# ...
