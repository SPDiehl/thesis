# %% [markdown]
# # Play By Play Analysis - '18-'19 Season

# %%
import pandas as pd
import numpy as np
import xgboost as xgb 
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn as sk

# %%
df = pd.read_csv("/Users/seandiehl/Downloads/matthew_2018-2019_pbp.csv")

# %%
pd.set_option("display.max_columns", None)
pd.set_option('display.float_format', lambda x: '%.0f' % x)

# %%
df.head()
# Out:
#    Unnamed: 0  X1  EVENTMSGACTIONTYPE  EVENTMSGTYPE  EVENTNUM   GAME_ID  \
# 0           1   0                   0            12         2  21801052
# 1           2   1                   0            10         4  21801052
# 2           3   2                   1             2         7  21801052
# 3           4   3                   0             4         8  21801052
# 4           5   4                   1             2         9  21801052
#
#                                HOMEDESCRIPTION  NEUTRALDESCRIPTION  \
# 0                                          NaN                 NaN
# 1  Jump Ball Horford vs. Jokic: Tip to Millsap                 NaN
# 2                                          NaN                 NaN
# 3                  Tatum REBOUND (Off:0 Def:1)                 NaN
# 4                   MISS Horford 15' Jump Shot                 NaN
#
#   PCTIMESTRING  PERIOD  PERSON1TYPE  PERSON2TYPE  PERSON3TYPE  PLAYER1_ID  \
# 0     12:00:00       1            0            0            0           0
# 1     12:00:00       1            4            5            5      201143
# 2     11:41:00       1            5            0            0      200794
# 3     11:39:00       1            4            0            0     1628369
# 4     11:34:00       1            4            0            0      201143
#
#    PLAYER1_NAME PLAYER1_TEAM_ABBREVIATION PLAYER1_TEAM_CITY  PLAYER1_TEAM_ID  \
# 0           NaN                       NaN               NaN              NaN
# 1    Al Horford                       BOS            Boston       1610612738
# 2  Paul Millsap                       DEN            Denver       1610612743
# 3  Jayson Tatum                       BOS            Boston       1610612738
# 4    Al Horford                       BOS            Boston       1610612738
#
#   PLAYER1_TEAM_NICKNAME  PLAYER2_ID  PLAYER2_NAME PLAYER2_TEAM_ABBREVIATION  \
# 0                   NaN           0           NaN                       NaN
# 1               Celtics      203999  Nikola Jokic                       DEN
# 2               Nuggets           0           NaN                       NaN
# 3               Celtics           0           NaN                       NaN
# 4               Celtics           0           NaN                       NaN
#
#   PLAYER2_TEAM_CITY  PLAYER2_TEAM_ID PLAYER2_TEAM_NICKNAME  PLAYER3_ID  \
# 0               NaN              NaN                   NaN           0
# 1            Denver       1610612743               Nuggets      200794
# 2               NaN              NaN                   NaN           0
# 3               NaN              NaN                   NaN           0
# 4               NaN              NaN                   NaN           0
#
#    PLAYER3_NAME PLAYER3_TEAM_ABBREVIATION PLAYER3_TEAM_CITY  PLAYER3_TEAM_ID  \
# 0           NaN                       NaN               NaN              NaN
# 1  Paul Millsap                       DEN            Denver       1610612743
# 2           NaN                       NaN               NaN              NaN
# 3           NaN                       NaN               NaN              NaN
# 4           NaN                       NaN               NaN              NaN
#
#   PLAYER3_TEAM_NICKNAME SCORE SCOREMARGIN           VISITORDESCRIPTION  \
# 0                   NaN   NaN         NaN                          NaN
# 1               Nuggets   NaN         NaN                          NaN
# 2                   NaN   NaN         NaN  MISS Millsap  3PT Jump Shot
# 3                   NaN   NaN         NaN                          NaN
# 4                   NaN   NaN         NaN                          NaN
#
#   WCTIMESTRING HOME_TEAM AWAY_TEAM  HOME_SCORE  AWAY_SCORE  TIME  TEAM  TYPE  \
# 0     19:41:00   Celtics   Nuggets           0           0     0   NaN   NaN
# 1     19:41:00   Celtics   Nuggets           0           0     0   NaN   NaN
# 2     19:41:00   Celtics   Nuggets           0           0    19   NaN   NaN
# 3     19:41:00   Celtics   Nuggets           0           0    21   NaN   NaN
# 4     19:41:00   Celtics   Nuggets           0           0    26   NaN   NaN
#
#    SUB_TYPE  ASSIST_PLAYER_ID  ASSIST_COUNT  BLOCK_PLAYER_ID  BLOCK_COUNT  \
# 0       NaN               NaN           NaN              NaN          NaN
# 1       NaN               NaN           NaN              NaN          NaN
# 2       NaN               NaN           NaN              NaN          NaN
# 3       NaN               NaN           NaN              NaN          NaN
# 4       NaN               NaN           NaN              NaN          NaN
#
#    REBOUND_PLAYER_ID REBOUND_TEAM  REBOUND_OFFENSIVE_COUNT  \
# 0                NaN          NaN                      NaN
# 1                NaN          NaN                      NaN
# 2                NaN          NaN                      NaN
# 3            1628369          NaN                        0
# 4                NaN          NaN                      NaN
#
#    REBOUND_DEFENSIVE_COUNT  JUMP_BALL_HOME_PLAYER_ID  \
# 0                      NaN                       NaN
# 1                      NaN                    201143
# 2                      NaN                       NaN
# 3                        1                       NaN
# 4                      NaN                       NaN
#
#    JUMP_BALL_AWAY_PLAYER_ID  JUMP_BALL_RETRIEVED_PLAYER_ID  \
# 0                       NaN                            NaN
# 1                    203999                         200794
# 2                       NaN                            NaN
# 3                       NaN                            NaN
# 4                       NaN                            NaN
#
#    SUB_ENTERED_PLAYER_ID  SUB_LEAVING_PLAYER_ID  FREE_THROW_PLAYER_ID  \
# 0                    NaN                    NaN                   NaN
# 1                    NaN                    NaN                   NaN
# 2                    NaN                    NaN                   NaN
# 3                    NaN                    NaN                   NaN
# 4                    NaN                    NaN                   NaN
#
#    FREE_THROW_NUM  FREE_THROW_TOTAL FREE_THROW_MADE  FOULED_BY_PLAYER_ID  \
# 0             NaN               NaN             NaN                  NaN
# 1             NaN               NaN             NaN                  NaN
# 2             NaN               NaN             NaN                  NaN
# 3             NaN               NaN             NaN                  NaN
# 4             NaN               NaN             NaN                  NaN
#
#    DRAWN_FOUL_PLAYER_ID  FOUL_COUNT TEAM_FOUL_COUNT FOUL_TYPE  \
# 0                   NaN         NaN             NaN       NaN
# 1                   NaN         NaN             NaN       NaN
# 2                   NaN         NaN             NaN       NaN
# 3                   NaN         NaN             NaN       NaN
# 4                   NaN         NaN             NaN       NaN
#
#    TECHNICAL_PLAYER_ID  DOUBLE_TECHNICAL_PLAYER_ID_1  \
# 0                  NaN                           NaN
# 1                  NaN                           NaN
# 2                  NaN                           NaN
# 3                  NaN                           NaN
# 4                  NaN                           NaN
#
#    DOUBLE_TECHNICAL_PLAYER_ID_2  DOUBLE_PERSONAL_PLAYER_ID_1  \
# 0                           NaN                          NaN
# 1                           NaN                          NaN
# 2                           NaN                          NaN
# 3                           NaN                          NaN
# 4                           NaN                          NaN
#
#    DOUBLE_PERSONAL_PLAYER_ID_2  DOUBLE_PERSONAL_FOUL_COUNT_1  \
# 0                          NaN                           NaN
# 1                          NaN                           NaN
# 2                          NaN                           NaN
# 3                          NaN                           NaN
# 4                          NaN                           NaN
#
#    DOUBLE_PERSONAL_FOUL_COUNT_2  COACH_TECHNICAL  SHOT_PLAYER_ID  \
# 0                           NaN              NaN             NaN
# 1                           NaN              NaN             NaN
# 2                           NaN              NaN          200794
# 3                           NaN              NaN             NaN
# 4                           NaN              NaN          201143
#
#    POINTS_SCORED  TOTAL_POINTS_SCORED SHOT_MADE SHOT_TYPE  STEAL_PLAYER_ID  \
# 0            NaN                  NaN       NaN       NaN              NaN
# 1            NaN                  NaN       NaN       NaN              NaN
# 2            NaN                  NaN     False      Shot              NaN
# 3            NaN                  NaN       NaN       NaN              NaN
# 4            NaN                  NaN     False      Shot              NaN
#
#    STEAL_COUNT  TURNOVER_PLAYER_ID  TURNOVER_COUNT  TEAM_TURNOVER_COUNT  \
# 0          NaN                 NaN             NaN                  NaN
# 1          NaN                 NaN             NaN                  NaN
# 2          NaN                 NaN             NaN                  NaN
# 3          NaN                 NaN             NaN                  NaN
# 4          NaN                 NaN             NaN                  NaN
#
#   TURNOVER_TYPE  POSSESSION_ID PERIOD_START PERIOD_END TIMEOUT_TYPE VIOLATION  \
# 0           NaN            NaN         True        NaN          NaN       NaN
# 1           NaN            NaN          NaN        NaN          NaN       NaN
# 2           NaN            NaN          NaN        NaN          NaN       NaN
# 3           NaN            NaN          NaN        NaN          NaN       NaN
# 4           NaN            NaN          NaN        NaN          NaN       NaN
#
#    VIOLATION_PLAYER_ID  EJECTION  EJECTION_PLAYER_ID  HOME_PLAYER_ID_1  \
# 0                  NaN       NaN                 NaN            202681
# 1                  NaN       NaN                 NaN            202681
# 2                  NaN       NaN                 NaN            202681
# 3                  NaN       NaN                 NaN            202681
# 4                  NaN       NaN                 NaN            202681
#
#    HOME_PLAYER_ID_2  HOME_PLAYER_ID_3  HOME_PLAYER_ID_4  HOME_PLAYER_ID_5  \
# 0            203935            201143            202694           1628369
# 1            203935            201143            202694           1628369
# 2            203935            201143            202694           1628369
# 3            203935            201143            202694           1628369
# 4            203935            201143            202694           1628369
#
#    AWAY_PLAYER_ID_1  AWAY_PLAYER_ID_2  AWAY_PLAYER_ID_3  AWAY_PLAYER_ID_4  \
# 0           1627750            203914            203999            200794
# 1           1627750            203914            203999            200794
# 2           1627750            203914            203999            200794
# 3           1627750            203914            203999            200794
# 4           1627750            203914            203999            200794
#
#    AWAY_PLAYER_ID_5  HOME_PLAYER_ID_1_PLAY_TIME  HOME_PLAYER_ID_2_PLAY_TIME  \
# 0            203115                         NaN                         NaN
# 1            203115                           0                           0
# 2            203115                          19                          19
# 3            203115                          21                          21
# 4            203115                          26                          26
#
#    HOME_PLAYER_ID_3_PLAY_TIME  HOME_PLAYER_ID_4_PLAY_TIME  \
# 0                         NaN                         NaN
# 1                           0                           0
# 2                          19                          19
# 3                          21                          21
# 4                          26                          26
#
#    HOME_PLAYER_ID_5_PLAY_TIME  AWAY_PLAYER_ID_1_PLAY_TIME  \
# 0                         NaN                         NaN
# 1                           0                           0
# 2                          19                          19
# 3                          21                          21
# 4                          26                          26
#
#    AWAY_PLAYER_ID_2_PLAY_TIME  AWAY_PLAYER_ID_3_PLAY_TIME  \
# 0                         NaN                         NaN
# 1                           0                           0
# 2                          19                          19
# 3                          21                          21
# 4                          26                          26
#
#    AWAY_PLAYER_ID_4_PLAY_TIME  AWAY_PLAYER_ID_5_PLAY_TIME
# 0                         NaN                         NaN
# 1                           0                           0
# 2                          19                          19
# 3                          21                          21
# 4                          26                          26

# %%
# Out:
# 837
#            Name
# 0           NaN
# 1    Al Horford
# 2  Paul Millsap
# 3  Jayson Tatum
# 4  Kyrie Irving
# 1281
#        IDs
# 0        0
# 1   201143
# 2   200794
# 3  1628369
# 4   202681

# %%
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# /Users/seandiehl/Desktop/thesis-git/thesis-data.ipynb Cell 7' in <module>
# ----> <a href='vscode-notebook-cell:/Users/seandiehl/Desktop/thesis-git/thesis-data.ipynb#ch0000003?line=0'>1</a> name_ids = pd.merge(names, ids)
#
# File ~/opt/anaconda3/envs/thesis-env/lib/python3.9/site-packages/pandas/core/reshape/merge.py:107, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      <a href='file:///Users/seandiehl/opt/anaconda3/envs/thesis-env/lib/python3.9/site-packages/pandas/core/reshape/merge.py?line=89'>90</a> @Substitution("\nleft : DataFrame or named Series")
#      <a href='file:///Users/seandiehl/opt/anaconda3/envs/thesis-env/lib/python3.9/site-packages/pandas/core/reshape/merge.py?line=90'>91</a> @Appender(_merge_doc, indents=0)
#      <a href='file:///Users/seandiehl/opt/anaconda3/envs/thesis-env/lib/python3.9/site-packages/pandas/core/reshape/merge.py?line=91'>92</a> def merge(
#    (...)
#     <a href='file:///Users/seandiehl/opt/anaconda3/envs/thesis-env/lib/python3.9/site-packages/pandas/core/reshape/merge.py?line=104'>105</a>     validate: str | None = None,
#     <a href='file:///Users/seandiehl/opt/anaconda3/envs/thesis-env/lib/python3.9/site-packages/pandas/core/reshape/merge.py?line=105'>106</a> ) -> DataFrame:
# --> <a href='file:///Users/seandiehl/opt/anaconda3/envs/thesis-env/lib/python3.9/site-packages/pandas/core/reshape/merge.py?line=106'>107</a>     op = _MergeOperation(
#     <a href='file:///Users/seandiehl/opt/anaconda3/envs/thesis-env/lib/python3.9/site-packages/pandas/core/reshape/merge.py?line=107'>108</a>         left,
#     <a href='file:///Users/seandiehl/opt/anaconda3/envs/thesis-env/lib/python3.9/site-packages/pandas/core/reshape/merge.py?line=108'>109</a>         right,
#     <a href='file:///Users/seandiehl/opt/anaconda3/envs/thesis-env/lib/python3.9/site-packages/pandas/core/reshape/merge.py?line=109'>110</a>         how=how,
#     <a href='file:///Users/seandiehl/opt/anaconda3/envs/thesis-env/lib/python3.9/site-packages/pandas/core/reshape/merge.py?line=110'>111</a>         on=on,
#     <a href='file:///Users/seandiehl/opt/anaconda3/envs/thesis-env/lib/python3.9/site-packages/pandas/core/reshape/merge.py?line=111'>112</a>         left_on=left_on,
#     <a href='file:///Users/seandiehl/opt/anaconda3/envs/thesis-env/lib/python3.9/site-packages/pandas/core/reshape/merge.py?line=112'>113</a>         right_on=right_on,
#     <a href='file:///Users/seandiehl/opt/anaconda3/envs/thesis-env/lib/python3.9/site-packages/pandas/core/reshape/merge.py?line=113'>114</a>         left_index=left_index,
#     <a href='file:///Users/seandiehl/opt/anaconda3/envs/thesis-env/lib/python3.9/site-packages/pandas/core/reshape/merge.py?line=114'>115</a>         right_index=right_index,
#     <a href='file:///Users/seandiehl/opt/anaconda3/envs/thesis-env/lib/python3.9/site-packages/pandas/core/reshape/merge.py?line=115'>116</a>         sort=sort,
#     <a href='file:///Users/seandiehl/opt/anaconda3/envs/thesis-env/lib/python3.9/site-packages/pandas/core/reshape/merge.py?line=116'>117</a>         suffixes=suffixes,
#     <a href='file:///Users/seandiehl/opt/anaconda3/envs/thesis-env/lib/python3.9/site-packages/pandas/core/reshape/merge.py?line=117'>118</a>         copy=copy,
#     <a href='file:///Users/seandiehl/opt/anaconda3/envs/thesis-env/lib/python3.9/site-packages/pandas/core/reshape/merge.py?line=118'>119</a>         indicator=indicator,
#     <a href='file:///Users/seandiehl/opt/anaconda3/envs/thesis-env/lib/python3.9/site-packages/pandas/core/reshape/merge.py?line=119'>120</a>         validate=validate,
#     <a href='file:///Users/seandiehl/opt/anaconda3/envs/thesis-env/lib/python3.9/site-packages/pandas/core/reshape/merge.py?line=120'>121</a>     )
#     <a href='file:///Users/seandiehl/opt/anaconda3/envs/thesis-env/lib/python3.9/site-packages/pandas/core/reshape/merge.py?line=121'>122</a>     return op.get_result()
#
# File ~/opt/anaconda3/envs/thesis-env/lib/python3.9/site-packages/pandas/core/reshape/merge.py:682, in _MergeOperation.__init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     <a href='file:///Users/seandiehl/opt/anaconda3/envs/thesis-env/lib/python3.9/site-packages/pandas/core/reshape/merge.py?line=677'>678</a>     # stacklevel chosen to be correct when this is reached via pd.merge
#     <a href='file:///Users/seandiehl/opt/anaconda3/envs/thesis-env/lib/python3.9/site-packages/pandas/core/reshape/merge.py?line=678'>679</a>     # (and not DataFrame.join)
#     <a href='file:///Users/seandiehl/opt/anaconda3/envs/thesis-env/lib/python3.9/site-packages/pandas/core/reshape/merge.py?line=679'>680</a>     warnings.warn(msg, FutureWarning, stacklevel=find_stack_level())
# --> <a href='file:///Users/seandiehl/opt/anaconda3/envs/thesis-env/lib/python3.9/site-packages/pandas/core/reshape/merge.py?line=681'>682</a> self._validate_specification()
#     <a href='file:///Users/seandiehl/opt/anaconda3/envs/thesis-env/lib/python3.9/site-packages/pandas/core/reshape/merge.py?line=683'>684</a> cross_col = None
#     <a href='file:///Users/seandiehl/opt/anaconda3/envs/thesis-env/lib/python3.9/site-packages/pandas/core/reshape/merge.py?line=684'>685</a> if self.how == "cross":
#
# File ~/opt/anaconda3/envs/thesis-env/lib/python3.9/site-packages/pandas/core/reshape/merge.py:1349, in _MergeOperation._validate_specification(self)
#    <a href='file:///Users/seandiehl/opt/anaconda3/envs/thesis-env/lib/python3.9/site-packages/pandas/core/reshape/merge.py?line=1346'>1347</a> common_cols = left_cols.intersection(right_cols)
#    <a href='file:///Users/seandiehl/opt/anaconda3/envs/thesis-env/lib/python3.9/site-packages/pandas/core/reshape/merge.py?line=1347'>1348</a> if len(common_cols) == 0:
# -> <a href='file:///Users/seandiehl/opt/anaconda3/envs/thesis-env/lib/python3.9/site-packages/pandas/core/reshape/merge.py?line=1348'>1349</a>     raise MergeError(
#    <a href='file:///Users/seandiehl/opt/anaconda3/envs/thesis-env/lib/python3.9/site-packages/pandas/core/reshape/merge.py?line=1349'>1350</a>         "No common columns to perform merge on. "
#    <a href='file:///Users/seandiehl/opt/anaconda3/envs/thesis-env/lib/python3.9/site-packages/pandas/core/reshape/merge.py?line=1350'>1351</a>         f"Merge options: left_on={self.left_on}, "
#    <a href='file:///Users/seandiehl/opt/anaconda3/envs/thesis-env/lib/python3.9/site-packages/pandas/core/reshape/merge.py?line=1351'>1352</a>         f"right_on={self.right_on}, "
#    <a href='file:///Users/seandiehl/opt/anaconda3/envs/thesis-env/lib/python3.9/site-packages/pandas/core/reshape/merge.py?line=1352'>1353</a>         f"left_index={self.left_index}, "
#    <a href='file:///Users/seandiehl/opt/anaconda3/envs/thesis-env/lib/python3.9/site-packages/pandas/core/reshape/merge.py?line=1353'>1354</a>         f"right_index={self.right_index}"
#    <a href='file:///Users/seandiehl/opt/anaconda3/envs/thesis-env/lib/python3.9/site-packages/pandas/core/reshape/merge.py?line=1354'>1355</a>     )
#    <a href='file:///Users/seandiehl/opt/anaconda3/envs/thesis-env/lib/python3.9/site-packages/pandas/core/reshape/merge.py?line=1355'>1356</a> if (
#    <a href='file:///Users/seandiehl/opt/anaconda3/envs/thesis-env/lib/python3.9/site-packages/pandas/core/reshape/merge.py?line=1356'>1357</a>     not left_cols.join(common_cols, how="inner").is_unique
#    <a href='file:///Users/seandiehl/opt/anaconda3/envs/thesis-env/lib/python3.9/site-packages/pandas/core/reshape/merge.py?line=1357'>1358</a>     or not right_cols.join(common_cols, how="inner").is_unique
#    <a href='file:///Users/seandiehl/opt/anaconda3/envs/thesis-env/lib/python3.9/site-packages/pandas/core/reshape/merge.py?line=1358'>1359</a> ):
#    <a href='file:///Users/seandiehl/opt/anaconda3/envs/thesis-env/lib/python3.9/site-packages/pandas/core/reshape/merge.py?line=1359'>1360</a>     raise MergeError(f"Data columns not unique: {repr(common_cols)}")
#
# MergeError: No common columns to perform merge on. Merge options: left_on=None, right_on=None, left_index=False, right_index=False
