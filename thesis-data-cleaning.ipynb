# %% [markdown]
# # Thesis Workspace 1
# ## Data Cleaning

# %% [markdown]
# First step: Import necessary libraries
# <br>
# for data cleaning, we shouldn't need much

# %%
import pandas as pd
import numpy as np
import xgboost as xgb
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# /Users/seandiehl/opt/anaconda3/envs/thesis-env/lib/python3.9/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index

# %%
play_by_play15 = pd.read_csv('/Users/seandiehl/Desktop/NBA Play By Play Data/NBA_PBP_2015-16.csv')
pd.set_option('display.max_columns', None)

# %%
play_by_play15.head()
# Out:
#                             URL GameType                       Location  \
# 0  /boxscores/201510270ATL.html  regular  Philips Arena Atlanta Georgia
# 1  /boxscores/201510270ATL.html  regular  Philips Arena Atlanta Georgia
# 2  /boxscores/201510270ATL.html  regular  Philips Arena Atlanta Georgia
# 3  /boxscores/201510270ATL.html  regular  Philips Arena Atlanta Georgia
# 4  /boxscores/201510270ATL.html  regular  Philips Arena Atlanta Georgia
#
#               Date     Time WinningTeam  Quarter  SecLeft AwayTeam  \
# 0  October 27 2015  8:00 PM         DET        1      720      DET
# 1  October 27 2015  8:00 PM         DET        1      701      DET
# 2  October 27 2015  8:00 PM         DET        1      699      DET
# 3  October 27 2015  8:00 PM         DET        1      697      DET
# 4  October 27 2015  8:00 PM         DET        1      681      DET
#
#                                             AwayPlay  AwayScore HomeTeam  \
# ...

# %%
play_by_play15['Shooter'] = play_by_play15['Shooter'].str.split('- ').str[1]
play_by_play15['Assister'] = play_by_play15['Assister'].str.split('- ').str[1]
play_by_play15['Blocker'] = play_by_play15['Blocker'].str.split('- ').str[1]
play_by_play15['Fouler'] = play_by_play15['Fouler'].str.split('- ').str[1]
play_by_play15['Fouled'] = play_by_play15['Fouled'].str.split('- ').str[1]
play_by_play15['Rebounder'] = play_by_play15['Rebounder'].str.split('- ').str[1]
play_by_play15['ViolationPlayer'] = play_by_play15['ViolationPlayer'].str.split('- ').str[1]
play_by_play15['FreeThrowShooter'] = play_by_play15['FreeThrowShooter'].str.split('- ').str[1]
play_by_play15['EnterGame'] = play_by_play15['EnterGame'].str.split('- ').str[1]
play_by_play15['LeaveGame'] = play_by_play15['LeaveGame'].str.split('- ').str[1]
play_by_play15['TurnoverPlayer'] = play_by_play15['TurnoverPlayer'].str.split('- ').str[1]
play_by_play15['TurnoverCauser'] = play_by_play15['TurnoverCauser'].str.split('- ').str[1]

# %%
play_by_play15.head()
# Out:
#                             URL GameType                       Location  \
# 0  /boxscores/201510270ATL.html  regular  Philips Arena Atlanta Georgia
# 1  /boxscores/201510270ATL.html  regular  Philips Arena Atlanta Georgia
# 2  /boxscores/201510270ATL.html  regular  Philips Arena Atlanta Georgia
# 3  /boxscores/201510270ATL.html  regular  Philips Arena Atlanta Georgia
# 4  /boxscores/201510270ATL.html  regular  Philips Arena Atlanta Georgia
#
#               Date     Time WinningTeam  Quarter  SecLeft AwayTeam  \
# 0  October 27 2015  8:00 PM         DET        1      720      DET
# 1  October 27 2015  8:00 PM         DET        1      701      DET
# 2  October 27 2015  8:00 PM         DET        1      699      DET
# 3  October 27 2015  8:00 PM         DET        1      697      DET
# 4  October 27 2015  8:00 PM         DET        1      681      DET
#
#                                             AwayPlay  AwayScore HomeTeam  \
# ...

# %%
play_by_play15['GameID'] = play_by_play15.groupby('URL').ngroup()+1

play_by_play15.head()
# Out:
#                             URL GameType                       Location  \
# 0  /boxscores/201510270ATL.html  regular  Philips Arena Atlanta Georgia
# 1  /boxscores/201510270ATL.html  regular  Philips Arena Atlanta Georgia
# 2  /boxscores/201510270ATL.html  regular  Philips Arena Atlanta Georgia
# 3  /boxscores/201510270ATL.html  regular  Philips Arena Atlanta Georgia
# 4  /boxscores/201510270ATL.html  regular  Philips Arena Atlanta Georgia
#
#               Date     Time WinningTeam  Quarter  SecLeft AwayTeam  \
# 0  October 27 2015  8:00 PM         DET        1      720      DET
# 1  October 27 2015  8:00 PM         DET        1      701      DET
# 2  October 27 2015  8:00 PM         DET        1      699      DET
# 3  October 27 2015  8:00 PM         DET        1      697      DET
# 4  October 27 2015  8:00 PM         DET        1      681      DET
#
#                                             AwayPlay  AwayScore HomeTeam  \
# ...
