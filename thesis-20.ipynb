# %% [markdown]
# # Thesis

# %% [markdown]
# #### Importing Data From the '20-'21 Season

# %%
import pandas as pd
import numpy as np
import xgboost as xgb
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn as sk

# %%
PBP20 = pd.read_csv('/Users/seandiehl/Desktop/NBA Play By Play Data/NBA_PBP_2020-21.csv')
pd.set_option('display.max_columns', None)

# %%
PBP20.head()
# Out:
#                             URL GameType                           Location  \
# 0  /boxscores/202012220BRK.html  regular  Barclays Center Brooklyn New York
# 1  /boxscores/202012220BRK.html  regular  Barclays Center Brooklyn New York
# 2  /boxscores/202012220BRK.html  regular  Barclays Center Brooklyn New York
# 3  /boxscores/202012220BRK.html  regular  Barclays Center Brooklyn New York
# 4  /boxscores/202012220BRK.html  regular  Barclays Center Brooklyn New York
#
#                Date     Time WinningTeam  Quarter  SecLeft AwayTeam  \
# 0  December 22 2020  7:00 PM         BRK        1      720      GSW
# 1  December 22 2020  7:00 PM         BRK        1      710      GSW
# 2  December 22 2020  7:00 PM         BRK        1      698      GSW
# 3  December 22 2020  7:00 PM         BRK        1      698      GSW
# 4  December 22 2020  7:00 PM         BRK        1      698      GSW
#
#                                             AwayPlay  AwayScore HomeTeam  \
# 0  Jump ball: J. Wiseman vs. D. Jordan (J. Harris...          0      BRK
# 1                                                NaN          0      BRK
# 2     Shooting foul by K. Irving (drawn by S. Curry)          0      BRK
# 3                   S. Curry makes free throw 1 of 2          1      BRK
# 4                   S. Curry makes free throw 2 of 2          2      BRK
#
#                            HomePlay  HomeScore Shooter ShotType ShotOutcome  \
# 0                               NaN          0     NaN      NaN         NaN
# 1  Turnover by D. Jordan (bad pass)          0     NaN      NaN         NaN
# 2                               NaN          0     NaN      NaN         NaN
# 3                               NaN          0     NaN      NaN         NaN
# 4                               NaN          0     NaN      NaN         NaN
#
#    ShotDist Assister Blocker  FoulType                 Fouler  \
# 0       NaN      NaN     NaN       NaN                    NaN
# 1       NaN      NaN     NaN       NaN                    NaN
# 2       NaN      NaN     NaN  shooting  K. Irving - irvinky01
# 3       NaN      NaN     NaN       NaN                    NaN
# 4       NaN      NaN     NaN       NaN                    NaN
#
#                  Fouled Rebounder ReboundType ViolationPlayer ViolationType  \
# 0                   NaN       NaN         NaN             NaN           NaN
# 1                   NaN       NaN         NaN             NaN           NaN
# 2  S. Curry - curryst01       NaN         NaN             NaN           NaN
# 3                   NaN       NaN         NaN             NaN           NaN
# 4                   NaN       NaN         NaN             NaN           NaN
#
#   TimeoutTeam      FreeThrowShooter FreeThrowOutcome FreeThrowNum EnterGame  \
# 0         NaN                   NaN              NaN          NaN       NaN
# 1         NaN                   NaN              NaN          NaN       NaN
# 2         NaN                   NaN              NaN          NaN       NaN
# 3         NaN  S. Curry - curryst01             make       1 of 2       NaN
# 4         NaN  S. Curry - curryst01             make       2 of 2       NaN
#
#   LeaveGame         TurnoverPlayer TurnoverType TurnoverCause TurnoverCauser  \
# 0       NaN                    NaN          NaN           NaN            NaN
# 1       NaN  D. Jordan - jordade01     bad pass           NaN            NaN
# 2       NaN                    NaN          NaN           NaN            NaN
# 3       NaN                    NaN          NaN           NaN            NaN
# 4       NaN                    NaN          NaN           NaN            NaN
#
#        JumpballAwayPlayer     JumpballHomePlayer           JumpballPoss
# 0  J. Wiseman - wisemja01  D. Jordan - jordade01  J. Harris - harrijo01
# 1                     NaN                    NaN                    NaN
# 2                     NaN                    NaN                    NaN
# 3                     NaN                    NaN                    NaN
# 4                     NaN                    NaN                    NaN

# %%
PBP20['Shooter'] = PBP20['Shooter'].str.split('- ').str[1]
PBP20['Assister'] = PBP20['Assister'].str.split('- ').str[1]
PBP20['Blocker'] = PBP20['Blocker'].str.split('- ').str[1]
PBP20['Fouler'] = PBP20['Fouler'].str.split('- ').str[1]
PBP20['Fouled'] = PBP20['Fouled'].str.split('- ').str[1]
PBP20['Rebounder'] = PBP20['Rebounder'].str.split('- ').str[1]
PBP20['ViolationPlayer'] = PBP20['ViolationPlayer'].str.split('- ').str[1]
PBP20['FreeThrowShooter'] = PBP20['FreeThrowShooter'].str.split('- ').str[1]
PBP20['EnterGame'] = PBP20['EnterGame'].str.split('- ').str[1]
PBP20['LeaveGame'] = PBP20['LeaveGame'].str.split('- ').str[1]
PBP20['TurnoverPlayer'] = PBP20['TurnoverPlayer'].str.split('- ').str[1]
PBP20['TurnoverCauser'] = PBP20['TurnoverCauser'].str.split('- ').str[1]
PBP20['JumpballAwayPlayer'] = PBP20['JumpballAwayPlayer'].str.split('-').str[1]
PBP20['JumpballHomePlayer'] = PBP20['JumpballHomePlayer'].str.split('-').str[1]
PBP20['JumpballPoss'] = PBP20['JumpballPoss'].str.split('-').str[1]

# %%
PBP20.head()
# Out:
#                             URL GameType                           Location  \
# 0  /boxscores/202012220BRK.html  regular  Barclays Center Brooklyn New York
# 1  /boxscores/202012220BRK.html  regular  Barclays Center Brooklyn New York
# 2  /boxscores/202012220BRK.html  regular  Barclays Center Brooklyn New York
# 3  /boxscores/202012220BRK.html  regular  Barclays Center Brooklyn New York
# 4  /boxscores/202012220BRK.html  regular  Barclays Center Brooklyn New York
#
#                Date     Time WinningTeam  Quarter  SecLeft AwayTeam  \
# 0  December 22 2020  7:00 PM         BRK        1      720      GSW
# 1  December 22 2020  7:00 PM         BRK        1      710      GSW
# 2  December 22 2020  7:00 PM         BRK        1      698      GSW
# 3  December 22 2020  7:00 PM         BRK        1      698      GSW
# 4  December 22 2020  7:00 PM         BRK        1      698      GSW
#
#                                             AwayPlay  AwayScore HomeTeam  \
# 0  Jump ball: J. Wiseman vs. D. Jordan (J. Harris...          0      BRK
# 1                                                NaN          0      BRK
# 2     Shooting foul by K. Irving (drawn by S. Curry)          0      BRK
# 3                   S. Curry makes free throw 1 of 2          1      BRK
# 4                   S. Curry makes free throw 2 of 2          2      BRK
#
#                            HomePlay  HomeScore Shooter ShotType ShotOutcome  \
# 0                               NaN          0     NaN      NaN         NaN
# 1  Turnover by D. Jordan (bad pass)          0     NaN      NaN         NaN
# 2                               NaN          0     NaN      NaN         NaN
# 3                               NaN          0     NaN      NaN         NaN
# 4                               NaN          0     NaN      NaN         NaN
#
#    ShotDist Assister Blocker  FoulType     Fouler     Fouled Rebounder  \
# 0       NaN      NaN     NaN       NaN        NaN        NaN       NaN
# 1       NaN      NaN     NaN       NaN        NaN        NaN       NaN
# 2       NaN      NaN     NaN  shooting  irvinky01  curryst01       NaN
# 3       NaN      NaN     NaN       NaN        NaN        NaN       NaN
# 4       NaN      NaN     NaN       NaN        NaN        NaN       NaN
#
#   ReboundType ViolationPlayer ViolationType TimeoutTeam FreeThrowShooter  \
# 0         NaN             NaN           NaN         NaN              NaN
# 1         NaN             NaN           NaN         NaN              NaN
# 2         NaN             NaN           NaN         NaN              NaN
# 3         NaN             NaN           NaN         NaN        curryst01
# 4         NaN             NaN           NaN         NaN        curryst01
#
#   FreeThrowOutcome FreeThrowNum EnterGame LeaveGame TurnoverPlayer  \
# 0              NaN          NaN       NaN       NaN            NaN
# 1              NaN          NaN       NaN       NaN      jordade01
# 2              NaN          NaN       NaN       NaN            NaN
# 3             make       1 of 2       NaN       NaN            NaN
# 4             make       2 of 2       NaN       NaN            NaN
#
#   TurnoverType TurnoverCause TurnoverCauser JumpballAwayPlayer  \
# 0          NaN           NaN            NaN          wisemja01
# 1     bad pass           NaN            NaN                NaN
# 2          NaN           NaN            NaN                NaN
# 3          NaN           NaN            NaN                NaN
# 4          NaN           NaN            NaN                NaN
#
#   JumpballHomePlayer JumpballPoss
# 0          jordade01    harrijo01
# 1                NaN          NaN
# 2                NaN          NaN
# 3                NaN          NaN
# 4                NaN          NaN

# %% [markdown]
# ### We Need to Ensure that the
